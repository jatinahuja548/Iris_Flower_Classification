# %% [markdown]
# # Task 1

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\jatin\Downloads\iris.csv")
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.shape
# Out:
# (150, 5)

# %%
df.variety.unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.tail()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
df.info
# Out:
# <bound method DataFrame.info of      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]>

# %%
df.isnull()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df1= df[df.variety=='Setosa']
df2= df[df.variety=='Versicolor']
df3= df[df.variety=='Virginica']

# %%
df1
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
df3
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 100           6.3          3.3           6.0          2.5  Virginica
# 101           5.8          2.7           5.1          1.9  Virginica
# 102           7.1          3.0           5.9          2.1  Virginica
# 103           6.3          2.9           5.6          1.8  Virginica
# 104           6.5          3.0           5.8          2.2  Virginica
# 105           7.6          3.0           6.6          2.1  Virginica
# 106           4.9          2.5           4.5          1.7  Virginica
# 107           7.3          2.9           6.3          1.8  Virginica
# 108           6.7          2.5           5.8          1.8  Virginica
# 109           7.2          3.6           6.1          2.5  Virginica
# 110           6.5          3.2           5.1          2.0  Virginica
# 111           6.4          2.7           5.3          1.9  Virginica
# 112           6.8          3.0           5.5          2.1  Virginica
# ...

# %%
plt.scatter(df1['sepal.length'],df1['sepal.width'], marker='+')
plt.scatter(df2['sepal.length'],df2['sepal.width'],color='green', marker='.')
plt.scatter(df3['sepal.length'],df3['sepal.width'],color='red', marker='*')

# %%
x= df[['sepal.length','sepal.width','petal.length','petal.width']]
y=df[['variety']]
x
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(x,y,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression(max_iter=1000)
lr.fit(X_train,y_train)
lr.predict(X_test)
# Out:
# c:\users\jatin\pycharmprojects\pythonproject\venv\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array(['Virginica', 'Setosa', 'Setosa', 'Virginica', 'Virginica',
#        'Setosa', 'Setosa', 'Virginica', 'Versicolor', 'Virginica',
#        'Setosa', 'Setosa', 'Versicolor', 'Setosa', 'Setosa', 'Setosa',
#        'Setosa', 'Virginica', 'Versicolor', 'Versicolor', 'Setosa',
#        'Virginica', 'Versicolor', 'Virginica', 'Virginica', 'Virginica',
#        'Virginica', 'Virginica', 'Setosa', 'Versicolor', 'Versicolor',
#        'Setosa', 'Setosa', 'Virginica', 'Versicolor', 'Virginica',
#        'Setosa', 'Virginica'], dtype=object)

# %%
lr.score(X_test, y_test)
# Out:
# 0.9736842105263158

# %%
X_test
# Out:
#      sepal.length  sepal.width  petal.length  petal.width
# 117           7.7          3.8           6.7          2.2
# 27            5.2          3.5           1.5          0.2
# 31            5.4          3.4           1.5          0.4
# 125           7.2          3.2           6.0          1.8
# 122           7.7          2.8           6.7          2.0
# 34            4.9          3.1           1.5          0.2
# 24            4.8          3.4           1.9          0.2
# 137           6.4          3.1           5.5          1.8
# 56            6.3          3.3           4.7          1.6
# 120           6.9          3.2           5.7          2.3
# 42            4.4          3.2           1.3          0.2
# 38            4.4          3.0           1.3          0.2
# 51            6.4          3.2           4.5          1.5
# 35            5.0          3.2           1.2          0.2
# 21            5.1          3.7           1.5          0.4
# ...

# %%
y_test
# Out:
#         variety
# 117   Virginica
# 27       Setosa
# 31       Setosa
# 125   Virginica
# 122   Virginica
# 34       Setosa
# 24       Setosa
# 137   Virginica
# 56   Versicolor
# 120   Virginica
# 42       Setosa
# 38       Setosa
# 51   Versicolor
# 35       Setosa
# 21       Setosa
# 3        Setosa
# 32       Setosa
# 140   Virginica
# 133   Virginica
# 73   Versicolor
# 14       Setosa
# 118   Virginica
# 79   Versicolor
# 123   Virginica
# 149   Virginica
# 104   Virginica
# 130   Virginica
# 148   Virginica
# 5        Setosa
# 86   Versicolor
# 68   Versicolor
# 11       Setosa
# 12       Setosa
# 100   Virginica
# 50   Versicolor
# 114   Virginica
# 9        Setosa
# 121   Virginica
